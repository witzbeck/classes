# %%
# std library imports

# 3rd party imports

# local imports
from samplespace import CoinSampleSpace
from prob_dist import geom_dist, show_dist

# %%
# number of heads before first tail
show_dist(geom_dist(0.5))
# number of heads following first tail
"""
    independent trials, so still binom
"""
# number of heads minus number of tails
"""
    independent trials, so still binom
"""
# number of tails times number of heads
# Out:
# '\n    independent trials, so still binom\n'

# %%
from prob_dist import neg_binom_dist
show_dist(neg_binom_dist(3, .25))
# Out:
# <AxesSubplot:xlabel='k', ylabel='P(X = k)'>
